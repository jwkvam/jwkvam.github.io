# %% [markdown]
# # Quantile Regression

# %%
import requests
from io import StringIO
import pandas as pd

# %%
r = requests.get('http://files.zillowstatic.com/research/public/State/State_Zhvi_AllHomes.csv')

# %%
df = pd.read_csv(StringIO(r.text))

# %%
df
# Out:
#               RegionName  1996-04  1996-05  1996-06  1996-07  1996-08  \
# 0             California   159800   159700   159200   158800   158800
# 1                  Texas      NaN      NaN      NaN      NaN      NaN
# 2               New York      NaN      NaN      NaN      NaN      NaN
# 3                Florida    87300    87400    87400    87600    87800
# 4               Illinois   113600   113800   113700   113000   112100
# 5           Pennsylvania    86100    86200    86000    85600    85500
# 6                   Ohio    86900    86900    86800    87200    87500
# 7               Michigan    91400    90600    90800    91500    90900
# 8                Georgia    91900    92900    93400    92900    92500
# 9         North Carolina    91000    91300    91900    93000    93600
# 10            New Jersey   142200   141800   141300   141100   141100
# 11              Virginia   115600   116000   116600   116700   116300
# ...
